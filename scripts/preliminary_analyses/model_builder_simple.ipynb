# %%
import spacy
import pandas as pd
import glob
import os
import numpy as np

import seaborn as sns
sns.set_style('darkgrid')

import nltk
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
#from nltk.corpus import twitter_samples, stopwords
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize
from nltk import FreqDist, classify, NaiveBayesClassifier
nltk.download('punkt')

from wordcloud import WordCloud


import re, string, random

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib

#setting pandas display options
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', -1)  # or 199

BASE_DIR = "/Users/karinalopez/Desktop/ds_projects/nlp/data/"
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/karinalopez/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# <ipython-input-16-ff4b5523cf02>:31: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)  # or 199

# %%
os.chdir(BASE_DIR + 'intermediate/')
df = pd.read_csv('athleisure_ethics_dataset_message_text_preprocessed.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'brand_name', 'parent_ company', 'notes', 'message_text',
#        'message_page_name', 'message_link', 'message_collected_data',
#        'good_on_you_date_sourced', 'pricepoint', 'overall_ethic_rating',
#        'good_on_you _link', 'Twitter Followers', 'FB Page Likes (total)',
#        'IG Followers', 'pinterest', 'social_media_numbers date sourced',
#        '# social media accounts on website (youtube, facebook, twitter, instagram, pinterest, tiktok, linkedin, strava, vimeo, tumbler, spotify, snapchat or weibo)',
#        'notes (optional)',
#        'get a number of different accounts posted; might need to hover to get the real number',
#        'message_text_sentence_count', 'message_text_preprocessed', 'tokenized',
#        'message_text_words_count', 'token_words_count'],
#       dtype='object')

# %%
text_df = df[['brand_name', 'message_text', 'overall_ethic_rating']]

# %% [markdown]
# # split text by periods into new rows

# %%
# Getting s as pandas series which has split on full stop and new sentence a new line
s = text_df["message_text"].str.split('.').apply(pd.Series,1).stack()
s.index = s.index.droplevel(-1) # to line up with df's index
s.name = 'message_text' # needs a name to join

# %%
# There are blank or emplty cell values after above process. Removing them
s.replace('', np.nan, inplace = True)
s.dropna(inplace = True)

# %%
del text_df['message_text']
text_df = text_df.join(s)
text_df.head(10)
# Out:
#               brand_name overall_ethic_rating  \
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
# 0  girlfriend collective  great
#
#                                                                                                                                                                                                                                                              message_text
# 0  When we started Girlfriend Collective our first goal was to be as transparent as possible
# 0   So many companies tout transparency but only offer flashy headlines instead of substance
# 0   We chose every part of our process, from our raw materials to our facilities to our partners, with care
# 0   We also discovered quickly that high end fit and feel is not a matter of cost, it’s a matter of time
# 0   We take the time to make sure every single one of our designs is so beautiful that you won’t cycle through it the next time you look through your closet
# 0   Beyond that, we wanted to find a community of people who cared about where their clothes come from as much as how they look
# 0   We're lucky to have found you
# 0   Take a look around, we're glad you're here
# 0   Is everything eco-friendly? We're like the earth's number one fan, so being eco-friendly is at the top of our priorities, as is giving you as much information as possible
# 0   Here’s a breakdown of each of our products and how it stacks up
# 0   Packaging: Our packaging is 100% recycled and recyclable, so don’t throw it away! Compressive Leggings + Bras: Made from 79% recycled polyester (or RPET) and 21% spandex, our leggings are made from 25 recycled post-consumer bottles and our bras are made from 11
# 0   LITE Leggings: Made from recycled fishing nets and other waste using ECONYL® yarn, our LITE fabric is made up of 83% recycled nylon and 17% spandex
# 0   Cupro: Our tees and tanks are 100% cupro, a delicate fiber made from waste the cotton industry leaves behind
# 0   Our yarn is made in a zero-waste, zero-emission facility in Japan, then constructed at our SA8000-certified factory in Hanoi
# 0   Reusable Pouch: Our reusable pouch is made with the same RPET as our bras and leggings
# 0   So not only is it reusable and adorable, it’s just as good for the earth as the rest of our line
# 0   How do you turn old water bottles into clothes? Did you know almost all synthetic activewear is made from plastic? We just make ours with materials that would otherwise clog landfills and pollute the earth
# 0   It all starts with 100% post-consumer water bottles that have their labels removed, are crushed into billions of miniscule chips, and then washed until they’re sparkling clean
# 0   After a bunch of science stuff with names like “polymerization,” you get a soft, recycled yarn that eliminates the need for petroleum and diverts water bottles from landfills at the same time
# 0   You can watch a video of the process here
# 0   Where do you manufacture? All of our textiles are made from recycled materials in our facility in Taiwan that specializes in eco-friendly and high-quality textiles, then cut-and-sewn in one of our partner facilities carefully chosen for their values and ethics
# 0   Our core factory is a magical place in Hanoi, Vietnam, that's SA8000 certified, guarantees fair wages, safe and healthy conditions, and zero forced or child labor
# 0   What’s SA8000? SA8000 is a social accountability standard and certificate developed by Social Accountability International (SAI)
# 0   They created this certification to help and protect workers worldwide by providing a standardized guideline to protect the integrity of workers’ conditions and wages
# 0   SA8000 overlaps with Fair Trade certification, but while Fair Trade is predominantly used for farming, SA8000 is a certification used in factory conditions
# 0   Why Vietnam and not the USA? You may not know it, but a lot of the best manufacturers for high-performance fabrics are located overseas
# 0   We know - we looked
# 0   The United States has great manufacturers for basic knitwear, but for our premium activewear the only machines up to the challenge were in Vietnam
# 0   Once we found our SA8000 certified manufacturer, we knew it was a match
# 0   Quality is everything to us, and we wanted to make sure we gave you the best product at the best price that you could find
# 0   How do we know you’re really fair-trade, and using recycled fabrics? We want to be as transparent as possible, so we're happy to share our certifications with you
# 0   Our factory is SA8000 certified, which you can read about here, and view our certification here
# 0   This certification promises that our operation adheres to those super strict regulations that keep factory employees well-paid, safe, and living healthy lives
# 0   Our recycled fabric is certified Standard 100 by Oeko-Tex, the world’s leader in testing fabrics to regulate harmful substances
# 0   They make sure every fabric’s origin and contents are totally up front, so you know exactly what you’re putting on your body
# 0   See our certifications here
# 0   Is your recycled polyester BPA free? Yes, it is
# 0   We understand why you’d want to check, because there is a lot of confusion about what kind of plastic is floating around (pun very much intended), so let’s talk about it
# 0   Plastics that contain BPA are polycarbonates, or the type of plastic specifically used in reusable water bottles
# 0   Our recycled PET is polyethylene terephthalate and is used in single use water bottles and food containers
# 0   This type of plastic has been repeatedly tested over 30 years for its safety
# 0   We say if it’s safe for your sandwich, it’s safe for your legs
# 0   What can I do about microfibers? Did you know all synthetic fabrics shed tiny pieces of plastic called microfibers in the wash? (It’s true
# 0   Even your favorite cozy fleece, swimwear, underwear, vintage dress, and, yep, Girlfriend leggings
# 0  ) We recommend washing all of your synthetics in a washing bag or filter
# 0   We make and sell one here that attaches to your home washing machine and captures these fibers before they can enter water streams, keeping microfibers out of the oceans and away from the creatures that inhabit them
# 0   Let’s clean this place up
# 0   How do you dye? Our fabric is dyed with eco-friendly dyes and the wastewater is carefully cleaned and cooled before it is released
# 0   (We even donate the dye mud to a local pavement facility where it’s recycled into sidewalks and roads
# 0   The unique dyeing process can result in some irregularities in color, which are not considered damages
# 0   Please note colors may run at first, so we recommend washing your new leggings separately or with similar colors just in case
# 0   Our Recycled Polyester Taiwan, where we source all of our post-consumer water bottles, once struggled to clean up mass amounts of waste resulting from rising living standards and soaring consumption
# 0   A small island nation of 23 million people, the government saw the danger of ignoring the problem, and through widespread change has transformed Taiwan into a world leader in recycling, with 55% of waste being recycled (as opposed to 35% in the US)
# 0   Recycling is a community affair in Taiwan
# 0   Each night people gather to sort their waste into containers as a community — recyclables, food waste, and garbage
# 0   Rather than leave, they stay and talk until the trucks come and pick it up, turning what could be a tedious affair into a connective one
# 0   Programs and volunteer groups have sprung up all over Taiwan to help bring this community spirit outside of city centers
# 0   We spent time documenting the Tzu Chi Foundation, which sets up micro-recycling centers in rural areas across Taipei
# 0   Run mostly by retired people, they set up drop off points to both give people access and education to recycling, and to promote environmental stewardship in their free time
# 0   Recycled Fabric Starts Somewhere
# 0   After all the bottles are sorted into their respective categories (#1, #2, #3, and #4 plastic), they are sent to their processing centers
# 0   Our leggings and bras are made from #1 plastic - or Polyethylene Terephthalate, also known as PET
# 0   Fun fact: All polyester (recycled or not) is derived from this type of plastic
# 0   Our bottles are sorted, cleaned, and chipped into feedstock at the center
# 0   Our processing center is pretty special
# 0   It’s owned by a respected Taiwanese family that has been at the forefront of the recycling industry for decades
# 0   We visited the facility, and were blown away by what we learned
# 0   It’s not only trusted by the Taiwanese government, it’s certified by them too
# 0   Being government certified means more than just having a certificate hanging on your wall saying that you can process plastic to resell
# 0   It means security measures are implemented and each facility is subject to accountability for how much plastic is taken in and how much is shipped out
# 0   Why is being certified so important? It is a well-known fact in the recycling industry that in places like China with loose certifications and accountability standards, many will lie about where they get their plastic
# 0   It’s actually much easier to buy new plastic water bottles and recycle them, than to collect and sort post-consumer bottles
# 0   Often, recyclers will recycle brand new bottles as post-consumer bottles and sell them at a higher price to brands that are trying to use recyclables in their products
# 0   Gross
# 0   At our facility, we have watched as bales of post-consumer bottles from all over Taiwan arrive at the facility
# 0   Each bale is weighed and logged
# 0   From there the bales go into a steam wash to remove caps and labels
# 0   After the caps and labels are removed, the bottles are sorted by color
# 0   We use the clear bottles for our fibers, and the colored bottles get sent elsewhere to be processed for myriad other uses
# 0   Once the color sorting is done, we shred them down into tiny chips, wash them again, and place them in transport bags to be shipped to our manufacturing facility
# 0   Each bag is weighed and logged again to make sure that the output is equal to input
# 0   This ensures that we have an accurate count for how many bottles were used and can verify that they were the same bottles processed at arrival
# 0   How Our Fabric Gets Made
# 0   As soon as our spinning mill takes the delivery of our raw PET chips from the recycling center, the bags of chips go through another wash, and are dried
# 0   Once they dry, the chips get sent to storage silos and are sent to a machine where the chips get heated up and extruded into long thick spaghetti like strands
# 0   From there, they are chipped down to little pellets
# 0   The pellets then get reheated and are extruded again to make superfine threads that are spun together into our yarn
# 0   From there they are spun onto large bobbins, packaged, and sent to our knitting factory
# 0   Our knitting process is unlike almost anything in the industry
# 0   Our fabric is softer and more stable than your standard single-jersey
# 0   This process requires time and precision, which means each of our knitting machines can only produce about 100 pairs-worth of fabric in a 24-hour period
# 0   Now that’s slow fashion
# 0   Once our fabric is knit, it gets sent to our dye house
# 0   Not to brag, but we’re going to brag about that, too
# 0   The dyeing process is often environmentally destructive, with many facilities opting for non eco-friendly dyes and chemicals, and choosing to dump wastewater freely into water sources like streams and rivers
# 0   If you look at photos of rivers that flow by cities involved in garment manufacturing, you will often notice bright blue or red water that enters the water tables that the community uses
# 0   This water not only damages the environment but is extremely harmful to people and crops that depend on their water sources to survive
# 0   Guess what? We weren’t into it, so we didn’t accept it
# 0   Our facility should be the standard for how wastewater should be treated
# 0   Every single drop of water that is used to dye our fabric gets sent to our wastewater treatment plant literally 100 feet away from the machines

# %%
os.chdir(BASE_DIR + 'intermediate/')
#text_df.to_csv('sentence_level_text_data.csv', index = False)

# %% [markdown]
# # Quick and dirty preprocessing

# %%
os.chdir(BASE_DIR + 'intermediate/')
#df = pd.read_csv('sentence_level_text_data.csv')
df = pd.read_csv('sentence_level_text_data.csv',
                 lineterminator = '\n')

# %%
# remove trailing white space
df['message_text'] = df['message_text'].str.strip()

# remove rows that contain only numbers
df = df[~df['message_text'].str.isnumeric()]
# Out:
# <ipython-input-51-a707925fb525>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['message_text'] = df['message_text'].str.strip()

# %%
os.chdir(BASE_DIR + 'intermediate/')
#df.to_csv('athleisure_ethics_dataset_message_text_preprocessed_2.csv', index = False)

# %% [markdown]
# # ran preprocessing row data script here

# %% [markdown]
# # map new values to each rating

# %%
os.chdir(BASE_DIR + 'intermediate/')
df = pd.read_csv('athleisure_ethics_dataset_message_text_preprocessed_3.csv')

# %%
#df['overall_ethic_rating'] = df['overall_ethic_rating'].str.replace("'", '')

# %%
df['overall_ethic_rating'].value_counts()
# Out:
# not good enough    4050
# good               2285
# its a start        1469
# we avoid           961
# great              630
# Name: overall_ethic_rating, dtype: int64

# %%
rating_dict = {'we avoid': 'not ethical', 'not good enough': 'not ethical', "it's a start": 'ethical', 'good': 'ethical', 'great': 'ethical'}
df['overall_ethic_rating'].value_counts()
# Out:
# not good enough    4050
# good               2285
# it's a start       1469
# we avoid           961
# great              630
# Name: overall_ethic_rating, dtype: int64

# %%
df['likely_rating'] = df['overall_ethic_rating'].replace(rating_dict)

# %%
df['likely_rating'].value_counts()
# Out:
# not ethical    5011
# ethical        4384
# Name: likely_rating, dtype: int64

# %%
# Check which ones are null
null_df = df[df.isna().any(axis=1)]
#display(null_df)

# %% [markdown]
# # Build a dirty model

# %%
#Now lets split the data
from sklearn.model_selection import train_test_split

data = df[['title_preprocessed','likely_rating']]

# %%
# Drop rows with nulls in 'title_preprocessed','likely_rating'
data = df.dropna()

# %%
print(data.shape)
# Out:
# (7091, 6)

# %%
train, test = train_test_split(data, shuffle = True, stratify = data.likely_rating, train_size = 50/data.shape[0], random_state = 50)

# %%
test, _ = train_test_split(test, shuffle = True, 
                           stratify = test.likely_rating, train_size = 7000/test.shape[0], random_state = 50)

# %%
train.shape, test.shape
# Out:
# ((50, 6), (7000, 6))

# %%
# Adverserial Validation
from scipy import sparse
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import StratifiedKFold


def adversarial_validation(X, Y, n_splits = 10):
    
    # Combine both datasets
    sparse_merge = sparse.vstack((X, Y))
    
    # Label the datasets
    y = np.array([0 for _ in range(X.shape[0])] + [1 for _ in range(Y.shape[0])])
    
    # Do 10 Fold CV 
    kfold = StratifiedKFold(n_splits = n_splits, shuffle = True)

    lr_auc = np.array([])
    rf_auc = np.array([])
    for train_idx, test_idx in kfold.split(sparse_merge, y):
    
        #Run Log Reg
        x_train, y_train = sparse_merge[train_idx], y[train_idx]
        x_test, y_test = sparse_merge[test_idx], y[test_idx]
        
        log_reg = SGDClassifier(loss = 'log')
        log_reg.fit(x_train, y_train)
        y_test_prob = log_reg.predict_proba(x_test)[:,1]
        lr_auc = np.append(lr_auc, roc_auc_score(y_test, y_test_prob))
        # Run RF
        rf = RandomForestClassifier(n_estimators = 100, n_jobs = -1)
        rf.fit(x_train, y_train)
        y_test_prob = rf.predict_proba(x_test)[:,1]
        rf_auc = np.append(rf_auc, roc_auc_score(y_test, y_test_prob))

    
    # Display results
    print('Logisitic Regression AUC : {:.3f}'.format(lr_auc.mean()))
    print('Random Forest AUC : {:.3f}'.format(rf_auc.mean()))

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.utils import shuffle 

bow = CountVectorizer()
x_train = bow.fit_transform(train.title_preprocessed.values)
x_test = bow.transform(test.title_preprocessed.values)

adversarial_validation(x_train, x_test[:50])
# Out:
# Logisitic Regression AUC : 0.374
# Random Forest AUC : 0.454

# %%
# Check how balanced datasets are

# %% [markdown]
# https://towardsdatascience.com/text-classification-with-extremely-small-datasets-333d322caee2
